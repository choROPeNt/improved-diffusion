# %%
import numpy as np

# %%
arr = np.empty([256,256])
print(arr.shape)
arr = arr.reshape((arr.shape[0],arr.shape[1],1))
print(arr.shape)
# Out:
# (256, 256)
# (256, 256, 1)

# %%
arr = np.transpose(arr, [2, 0, 1])
arr.shape
# Out:
# (1, 256, 256)
