# %%
import numpy as np

import h5py

from pathlib import Path

import matplotlib.pyplot as plt

# %%
file_path = Path("/Volumes/CT-Data/CT_Hys/EPP_2020-12-09.h5")

# %%
with h5py.File(file_path,"r") as f:
    data = f["volume"]
    print(data.dtype)
    plt.imshow(data[1400,500:1700,500:1700])

    vol = data[200:1400,500:1700,500:1700]
# Out:
# uint16

# %%
vol.shape
# Out:
# (1200, 1200, 1200)

# %%
with h5py.File("/Volumes/CT-Data/CT_Hys/EPP_2020-12-09.train.h5","w") as f:
    f.create_dataset("volume",data=vol,compression="gzip")
